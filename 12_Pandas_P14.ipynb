# %% [markdown]
# <h2>1) Uso de <code>.sort_values()</code> para ordenar DataFrames por una o varias columnas. Parámetro <code>inplace=True</code></h2>
#
# <p>
# El método <code>.sort_values()</code> ordena las filas de un DataFrame según los valores de una o más columnas.
# </p>
#
# <h3>1.1 Ordenar por una columna</h3>
# <pre><code>import pandas as pd
#
# df = pd.DataFrame({
#     "nombre": ["Ana", "Luis", "Sofía", "Pedro"],
#     "edad": [21, 19, 21, 18],
#     "nota": [5.8, 6.4, 5.9, 5.1]
# })
#
# df_ordenado = df.sort_values(by="nota")
# df_ordenado</code></pre>
#
# <h3>1.2 Ordenar por varias columnas</h3>
# <p>
# Cuando se ordena por varias columnas, primero se usa la primera columna indicada y, si hay empates, se utiliza la siguiente.
# </p>
# <pre><code>df_ordenado2 = df.sort_values(by=["edad", "nota"])
# df_ordenado2</code></pre>
#
# <h3>1.3 Parámetro <code>inplace=True</code></h3>
# <p>
# Si se usa <code>inplace=True</code>, el DataFrame original se modifica directamente.
# En este caso, el método no entrega un nuevo DataFrame para asignar.
# </p>
# <pre><code>df.sort_values(by="nota", inplace=True)
# df</code></pre>
#
# <p>
# Evite asignar el resultado cuando use <code>inplace=True</code>.
# </p>
# <pre><code># Ejemplo incorrecto (evitar):
# # df = df.sort_values(by="nota", inplace=True)</code></pre>
#
# <hr>
#
# <h2>2) Diferencia entre datos categóricos y no categóricos</h2>
#
# <h3>2.1 Datos categóricos</h3>
# <p>
# Son datos que representan categorías o grupos. Sirven para clasificar.
# </p>
# <ul>
#   <li>Ejemplos: sección, carrera, ciudad, tipo, estado.</li>
#   <li>Se suelen analizar con conteos y frecuencias.</li>
# </ul>
#
# <h3>2.2 Datos no categóricos</h3>
# <p>
# Son datos que representan cantidades o mediciones, normalmente numéricas.
# </p>
# <ul>
#   <li>Ejemplos: edad, nota, salario, tiempo.</li>
#   <li>Se suelen analizar con operaciones como promedio, mínimo o máximo.</li>
# </ul>
#
# <p>
# La diferencia es importante porque los análisis cambian según el tipo de dato.
# Por ejemplo, es útil contar cuántas veces aparece una categoría, pero no tiene sentido promediar nombres de categorías.
# </p>
#
# <hr>
#
# <h2>3) Uso de <code>unique()</code>, <code>value_counts()</code>, <code>isin()</code></h2>
#
# <p>
# Estas funciones permiten explorar valores categóricos, contar frecuencias y filtrar por pertenencia.
# </p>
#
# <pre><code>df2 = pd.DataFrame({
#     "seccion": ["A", "B", "A", "C", "B", "A"],
#     "nota": [6.1, 5.5, 6.7, 4.9, 5.8, 6.0]
# })
#
# df2</code></pre>
#
# <h3>3.1 <code>unique()</code></h3>
# <p>
# Devuelve los valores distintos de una columna.
# </p>
# <pre><code>df2["seccion"].unique()</code></pre>
#
# <h3>3.2 <code>value_counts()</code></h3>
# <p>
# Cuenta cuántas veces aparece cada valor en una columna.
# </p>
# <pre><code>df2["seccion"].value_counts()</code></pre>
#
# <h3>3.3 <code>isin()</code></h3>
# <p>
# Indica si cada valor de una columna pertenece a un conjunto de valores.
# El resultado es una serie booleana que se puede usar para filtrar.
# </p>
# <pre><code>mask = df2["seccion"].isin(["A", "C"])
# mask</code></pre>
#
# <p>
# Filtrado usando <code>isin()</code>:
# </p>
# <pre><code>df2_filtrado = df2[df2["seccion"].isin(["A", "C"])]
# df2_filtrado</code></pre>
#
# <hr>
#
# <h2>4) Uso de <code>.groupby()</code> por categoría</h2>
#
# <p>
# El método <code>.groupby()</code> agrupa filas que comparten la misma categoría, permitiendo obtener un resumen por grupo.
# </p>
#
# <h3>4.1 Ejemplo: promedio por categoría</h3>
# <pre><code>df2.groupby("seccion")["nota"].mean()</code></pre>
#
# <p>
# En este ejemplo, se agrupan las filas por <code>seccion</code> y se calcula el promedio de <code>nota</code> para cada grupo.
# </p>
# ```

# %% [markdown]
# <h2>Ejercicio 1: Ordenamiento y tipo de datos</h2>
#
# <p>
# Trabaja con el siguiente DataFrame y realiza las tareas solicitadas.
# </p>
#
# <pre><code>import pandas as pd
#
# df = pd.DataFrame({
#     "estudiante": ["Ana", "Luis", "Sofía", "Pedro", "Camila"],
#     "seccion": ["A", "B", "A", "C", "B"],
#     "edad": [21, 19, 21, 18, 20],
#     "nota": [5.8, 6.4, 5.9, 5.1, 6.0]
# })
#
# df</code></pre>
#
# <ol>
#   <li>
#     Ordena el DataFrame por la columna <code>nota</code> y guárdalo en una nueva variable.
#   </li>
#   <li>
#     Ordena el DataFrame por <code>seccion</code> y luego por <code>edad</code>.
#   </li>
#   <li>
#     Ordena el DataFrame original por <code>edad</code> usando <code>inplace=True</code>.
#   </li>
#   <li>
#     Indica qué columnas del DataFrame son <b>categóricas</b> y cuáles son <b>no categóricas</b>.
#   </li>
# </ol>

# %%
import pandas as pd

# DataFrame base
df = pd.DataFrame({
    "estudiante": ["Ana", "Luis", "Sofía", "Pedro", "Camila"],
    "seccion": ["A", "B", "A", "C", "B"],
    "edad": [21, 19, 21, 18, 20],
    "nota": [5.8, 6.4, 5.9, 5.1, 6.0]
})


# 1 Ordena el DataFrame por la columna nota y guárdalo en una nueva variable.

df_ordenado_nota = df.sort_values(by="nota")

# 2 Ordena el DataFrame por seccion y luego por edad.

df_ordenado_seccion_edad = df.sort_values(by=["seccion", "edad"])

# 3 Ordena el DataFrame original por edad.

df.sort_values(by = "edad", inplace=True )

# 4 Indica qué columnas del DataFrame son categóricas y cuáles son no categóricas.

categoricas = ["estudiante", "seccion"]
no_categoricas = ["edad", "nota"]


# El estudiante esta de aceurdo con las practicas de clase

# 1-Descauerdo // 2-Acuerdo // 3-Neutro

# STR --> (Palabra/Codigo) == Categorico
# Numero --> No siempre es no-categorico, puede ser categorico

# MATRICULA -> CATEGORICO (Numeros)
# Cedula    -> CATEGORICO (Numeros)

# %% [markdown]
# <h2>Ejercicio 2: Exploración de datos categóricos</h2>
#
# <p>
# A partir del siguiente DataFrame, utiliza funciones de Pandas para explorar la columna categórica <code>seccion</code>.
# </p>
#
# <pre><code>import pandas as pd
#
# df = pd.DataFrame({
#     "estudiante": ["Ana", "Luis", "Sofía", "Pedro", "Camila", "Jorge"],
#     "seccion": ["A", "B", "A", "C", "B", "A"],
#     "nota": [5.8, 6.4, 5.9, 5.1, 6.0, 5.5]
# })
#
# df</code></pre>
#
# <ol>
#   <li>
#     Obtén los valores únicos de la columna <code>seccion</code>.
#   </li>
#   <li>
#     Cuenta cuántas veces aparece cada sección usando <code>value_counts()</code>.
#   </li>
#   <li>
#     Filtra el DataFrame para quedarte solo con los estudiantes de las secciones <code>A</code> y <code>B</code>
#     usando <code>isin()</code>.
#   </li>
# </ol>

# %%
import pandas as pd


df = pd.DataFrame({
    "estudiante": ["Ana", "Luis", "Sofía", "Pedro", "Camila", "Jorge"],
    "seccion": ["A", "B", "A", "C", "B", "A"],
    "nota": [5.8, 6.4, 5.9, 5.1, 6.0, 5.5]
})


# 1) Obtén los valores únicos de la columna seccion.   !!! .unique()

secciones_unicas = df["seccion"].unique()  # --> Obtenemos valores unicos - de la columna Seccion - del "df"



# 2) Cuenta cuántas veces aparece cada sección usando value_counts()


conteo_secciones = df["seccion"].value_counts() # -> Contamos los valores - de la columna Seccion - del "df"



# 3 Filtra el DataFrame para quedarte solo con los estudiantes
#   de las secciones A y B


condicion_booleana = df["seccion"].isin(["A","B"]) # Que la fila tenga A, o B.


df_filtrado = df[condicion_booleana]

print(df)

print(f"\nEl dataframe FILTRADO por A, o B es: \n {df_filtrado}")
# Out:
#   estudiante seccion  nota
# 0        Ana       A   5.8
# 1       Luis       B   6.4
# 2      Sofía       A   5.9
# 3      Pedro       C   5.1
# 4     Camila       B   6.0
# 5      Jorge       A   5.5
#
# El dataframe FILTRADO por A, o B es:
#    estudiante seccion  nota
# 0        Ana       A   5.8
# 1       Luis       B   6.4
# 2      Sofía       A   5.9
# 4     Camila       B   6.0
# 5      Jorge       A   5.5

# %% [markdown]
# <h2>Ejercicio 3: Promedio por categoría con <code>groupby()</code></h2>
#
# <p>
# Usa el siguiente DataFrame para calcular el promedio de notas por sección.
# </p>
#
# <pre><code>import pandas as pd
#
# df = pd.DataFrame({
#     "estudiante": ["Ana", "Luis", "Sofía", "Pedro", "Camila", "Jorge"],
#     "seccion": ["A", "B", "A", "C", "B", "A"],
#     "nota": [5.8, 6.4, 5.9, 5.1, 6.0, 5.5]
# })
#
# df</code></pre>
#
# <ol>
#   <li>
#     Agrupa el DataFrame por la columna <code>seccion</code>.
#   </li>
#   <li>
#     Calcula el promedio de la columna <code>nota</code> para cada sección usando <code>groupby()</code>.

# %%
import pandas as pd

df = pd.DataFrame({
    "estudiante": ["Ana", "Luis", "Sofía", "Pedro", "Camila", "Jorge"],
    "seccion": ["A", "B", "A", "C", "B", "A"],
    "nota": [5.8, 6.4, 5.9, 5.1, 6.0, 5.5]
})

print(f"\n El Dataframe ORIGINAL es: \n{df}\n")

# AGRUPAR por Secciones!! Es decir, GRUPO A, Grupo B, Grupo C
# PROMEDIAR las CALIFICACIONES de cada Seccion

promedio_por_seccion = df.groupby("seccion")["nota"].mean()
#                      || GENERAR 3 GRUPOS ||LLAMAR||PROM||
#                            A , B , C


# A - (Calificaciones A) - > PROMEDIO C. A
# B - (Calificaciones B) - > PROMEDIO C. B
# C - (Calificaciones C) - > PROMEDIO C. C

print(promedio_por_seccion)
# Out:
#  El Dataframe ORIGINAL es:
#   estudiante seccion  nota
# 0        Ana       A   5.8
# 1       Luis       B   6.4
# 2      Sofía       A   5.9
# 3      Pedro       C   5.1
# 4     Camila       B   6.0
# 5      Jorge       A   5.5
#
# seccion
# A    5.733333
# B    6.200000
# C    5.100000
# Name: nota, dtype: float64

# %% [markdown]
# # REGISTREN ASISTENCIA EN EL CHAT !!!!
